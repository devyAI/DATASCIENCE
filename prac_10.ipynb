# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.drop('Id', axis=1)
df.hist(figsize=(10,8))
plt.show()

# %%
df.boxplot(figsize=(5,5))
plt.show()

# %%
sort_data = np.sort(df['SepalWidthCm'])
mean = np.mean(sort_data)
std = np.std(sort_data)
print('mean of the dataset is', mean)
print('std. deviation is', std)
threshold = 1
outlier = []
for i in sort_data:
    z = (i-mean)/std
    if z > threshold:
        outlier.append(float(i))
print('outlier in dataset is', outlier)
# Out:
# mean of the dataset is 3.054
# std. deviation is 0.43214658007054346
# outlier in dataset is [3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.6, 3.6, 3.6, 3.7, 3.7, 3.7, 3.8, 3.8, 3.8, 3.8, 3.8, 3.8, 3.9, 3.9, 4.0, 4.1, 4.2, 4.4]

# %%
sns.boxplot(data=df,x="Species",y="SepalWidthCm")
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.histplot(df['PetalLengthCm'], kde=True, bins = 30 )
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>
